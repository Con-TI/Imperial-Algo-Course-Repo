# %% [markdown]
# # Python Knowledge:
# ## How Python works and basics
# - OOP and differences with C++:
# - Built-in scope:
#
# ## Datatypes
# - Numeric:
#     - int
#     - float
#     - complex
# - str
#     - Some important methods:
#         - split()
#         - .join()
#         - count()
#         - ord()
#         - chr()
#         - isalpha()
#         - isdigit()
#         - startswith()
#         - upper()
#         - lower()
#         - strip()
# - Sequence:
#     - list
#     - tuple
#     - range
# - Mapping:
#     - dict
#     - set
#     - frozenset
# - bool:
# - Binary:
#     - bytes
#     - bytearray
#     - memoryview
# - None:
# - Declaring custom datatypes using enums:
#
# ## Everything print() related
# - Format specifiers
# - sep, end, file and flush arguments
#
# ## General basic functions
# - index()
# - len()
# - all()
# - any()
# - bin()
# - input()
# - max()
# - min()
# - sum()
# - pow()
# - repr()
# - reversed()
# - round()
# - sorted()
#
# ## Operators and some dunder methods
# - Truth value operators
# - Comparators
# - General arithmetic operators
# - Numeric only operators: Bitwise manipulation
#
# ## Sorting in Python
#
# ## Control flow
# - if elif else:
# - match case guard:
# - try except else:
#
# ## Iteration
# - for loops
#     - basic structure
#     - adding the else statement
# - while loops
#     - basic while
# - break and continue statements
# - The walrus operator
# - Extra methods:
#     - enumerate
#     - zip
#     - itertools library
#
# ## Functions
# - Function objects
#     - core attributes to function objects
# - Creating a function
#     - def and lambda declarations
#     - args and kwargs
#     - Type hinting
#     - Scopes: local, global and nonlocal assignment
#     - return keyword
#     - partial functions
#     - single and dynamic dispatch
# - Generators
# - Recursion and stack frames
# - Some function decorators
#     - @log
#     - @functools.singledispatch
#     - @functionname.register
#     - @wraps
#     - @multimethod
#     - @functools.lru_cache
#
# ## Classes and OOP
# - Creating a new class:
#     - The __init__ function and __new__ function:
#     - Class and instance variables and their mutability considerations:
#     - Class inheritance and multi inheritance:
#         - How to inherit and multi inherit:
#         - __init_subclasses__
#         - super method
#     - Some useful dunder methods:
#         - __repr__
#         - __getattr__
#         - __setattr__
#     - self keyword and defining functions/methods outside of classes:
# - Instantiating an object:
#     - Initializing a class object:
#     - Object pointers, __dict__, __slots__ and heap memory:
#     - Method resolution order (MRO):
#     - Method objects vs function objects:
# - Efficiency gains:
#     - Dataclasses:
#     - property:
#     - static and class methods:
#     - Meta classes:
#     - Dynamic class creation using type:
#     - Class composition vs inheritance
# - Other extra stuff:
#     - Making classes hashable
#     - isinstance, issubclass
#
# ## Decorators in general
# - How they work and decorators on classes vs functions
#     - Basics:
#     - Bottom-up execution:
#     - Decorators on classes
#     - Decorators on functions
# - Defining decorators
#     - Function decorators
#     - Class decorators
#     - Parametrized decorators/decorator factories
#     - Decorator classes
#
# ## Modules
# - Creating a module
#
# - Deep dive into importing
#
# - Creating a python pip-able package
#
# - Virtual environments
#
# ## Context management
# - with and open keywords
# - writing and reading
# - Context manager classes
#
# ## Memory management with del: usage and caveats
#
# ## Pickling in Python
#
# ## Built-in DSA implementations in Python
# - heaps/priority queues
# - deques

# %% [markdown]
# # Exploring Python Libraries (Standard library and third-party libraries)
# ## File paths, System related things:
# ### os
# ### glob
# ### sys
#
# ## Networking and internet capabilites
# ### Establishing connections:
# #### requests
# #### websocket
# #### socket
# ### Webscraping-related:
# #### beautifulsoup
# #### selenium
# #### scrapy
#
# ## CPU manipulation (Parallelism and concurrency)
# #### multiprocessing
# #### concurrent
# #### subprocess
# #### sched
# #### queue
# #### _thread
# #### asyncio
#
# ## Dealing with data and math
# ### json
# ### Pandas
# ### Polars
# ### Numpy
# ### jax
# ### jit
#
# ## ML
# ### scikit-learn
# ### tensorflow
# ### Pytorch
#
# ## Miscellaneous
# ### pprint
# ### datetime

# %% [markdown]
# # Using C/C++ with Python
# ## Cython
