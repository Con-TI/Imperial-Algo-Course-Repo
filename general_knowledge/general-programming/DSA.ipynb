# %% [markdown]
# # A list of some techniques and terms in DSA

# %% [markdown]
# Hashmap
#
# Hashset
#
# Hashtable
#
# Sorting algorithms
#
# Memoization
#
# K-sums
#
# Two pointers
#
# Prefix sum
#
# Queue
#
# Stack
#
# Binary search
#
# Linked List
#
# Fast and slow pointers
#
# Negative marking
#
# Doubly linked lists
#
# Circular queue
#
# Trees:
# - In order traversal
#
# - pre order traversal
#
# - post order traversal
#
# - morris traversal
#
# - z-algorithm for pattern matching
#
# - Binary search tree
#
# - Quad trees
#
#
# Priority Queue, Minheaps and Maxheaps
#
# Scheduling
#
# Backtracking
#
# Backtracking with pruning
#
# Depth first search
#
# Breadth first search
#
# Shallow and deep copying
#
# Graph specific algorithms:
# - Multisource DFS/BFS
#
# - DFS for cycle detection
#
# - Kahn's toposort
#
# - Disjoint set union
#
# - Floyd Warshall algorithm
#
# Dynamic programming related
# - Top Down Dynamic programming
# - Bottom Up Dynamic programming
#
# Bit masking with a single int
#
# Bit masking with an array stored
